# %% [markdown]
# # Twitter Sentiment Analysis!
# **In this age, in this country, public sentiment is everything. With it, nothing can fail; against it, nothing can succeed. ~ Abraham Lincoln**
#
# Sentiment analysis is a natural language processing technique used to determine whether data is positive, negative, or neutral. Sentiment analysis is often performed on textual data to help businesses monitor brand and product sentiment in customer feedback and understand customer needs. Corporations can also use sentiment analysis to understand and react to the general stigma around their company. End users can also use sentiment analysis as buy and sell signals for the stocks they own.
#
# *In this project, I will train a machine learning model on tweets and then use the tweet's sentiment to predict if stock prices will go up or down.*

# %%
import pandas as pd
import numpy as np

#imports to plot bar and line graphs
import matplotlib.pyplot as plt
from matplotlib.offsetbox import (OffsetImage, AnnotationBbox, TextArea)
from matplotlib.patches import ArrowStyle 

#imports to preprocess the tweet data
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

#imports to train machine learning models
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

#import to get stock data
from yahoo_fin.stock_info import get_data

# %% [markdown]
# # Importing the data
# Using the pandas' library, I am reading a CSV file and converting it to a data frame. I also save the number of positive and negative tweets I have in variables because I will use them in the next section.

# %%
df_nonClean = pd.read_csv("Financial Tweets.csv", encoding='iso-8859-1')
pos_tweet_count_before = len(df_nonClean.loc[df_nonClean['Sentiment'] == 'positive'])
neg_tweet_count_before = len(df_nonClean.loc[df_nonClean['Sentiment'] == 'negative'])
df_nonClean
# Out:
#         Sentiment                                             Tweets
# 0        negative  is upset that he can't update his Facebook by ...
# 1        negative  @Kenichan I dived many times for the ball. Man...
# 2        negative    my whole body feels itchy and like its on fire
# 3        negative  @nationwideclass no, it's not behaving at all....
# 4        negative                      @Kwesidei not the whole crew
# ...           ...                                                ...
# 1048570  positive           My GrandMa is making Dinenr with my Mum
# 1048571  positive  Mid-morning snack time... A bowl of cheese noo...
# 1048572  positive  @ShaDeLa same here  say it like from the Termi...
# 1048573  positive             @DestinyHope92 im great thaanks  wbuu?
# 1048574  positive               cant wait til her date this weekend
#
# [1048575 rows x 2 columns]

# %% [markdown]
# # Resizing the Data
# This data has two problems.
#
#     1) This data has 1.4 million tweets. It will take a long time for my laptop to process 1.4 million tweets.
#
#     2) This data also has an uneven amount of positive and negative tweets. If I process the data without balancing it out, the model will be biased towards negative tweets.
#
# To solve the problems, I will first split the data frame into two smaller data frames called "df_nonClean_pos" representing positive tweets, and "df_nonClean_neg" representing negative tweets. Then I will take a random sample of 200,000 tweets from each data frame and then combine the two data frames again. Now, I will have a data frame of 400,000 tweets, with 200,000 negative tweets and 200,000 positive tweets.

# %%
df_nonClean_pos = df_nonClean.loc[df_nonClean['Sentiment'] == "positive"]
df_nonClean_neg = df_nonClean.loc[df_nonClean['Sentiment'] == "negative"]

df_nonClean_pos = df_nonClean_pos.sample(frac=200000/df_nonClean_pos.shape[0])
df_nonClean_neg = df_nonClean_neg.sample(frac=200000/df_nonClean_neg.shape[0])

df_nonClean = pd.concat([df_nonClean_pos, df_nonClean_neg])

# %%
def plot_my_bargraph(ax, x, count, colors, ymin, ymax, title):
    plt.rcParams["figure.figsize"] = [16, 4]
    plt.rc('axes', titlesize=13)
    ax.set_facecolor('#536490')
    ax.set_ylim(ymin, ymax)
    ax.grid(axis = 'y', zorder = '1', c = 'w', alpha = 1, lw = .6)
    ax.spines['bottom'].set_color('w')
    ax.spines['top'].set_color('w')
    ax.spines['right'].set_color('w')
    ax.spines['left'].set_color('w')
    ax.tick_params(axis='x', colors='w')
    ax.tick_params(axis='y', colors='w')
    ax.yaxis.label.set_color('w')
    ax.xaxis.label.set_color('w')
    ax.title.set_color('w')
    ax.set_title(title)
    return  ax.bar(x, count, color = colors, width = .1, zorder = 3, alpha = .95)

pos_tweet_count = len(df_nonClean.loc[df_nonClean['Sentiment'] == 'positive'])
neg_tweet_count = len(df_nonClean.loc[df_nonClean['Sentiment'] == 'negative'])
fig = plt.figure()
fig, ax = plt.subplots(1, 2, facecolor='#576692')
plot_my_bargraph(ax[0], ["Positive Tweets", "Negative Tweets"], [pos_tweet_count_before, neg_tweet_count_before], ['#ffc801', '#ffa238'], 0, 900000, 'Tweet Breakdown before data resizing')
plot_my_bargraph(ax[1], ["Positive Tweets", "Negative Tweets"], [pos_tweet_count, neg_tweet_count], ['#ffc801', '#ffa238'], 0, 900000, "Tweet Breakdown after data resizing")
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ## Cleaning the data
# On most occasins, the insital data has a lot of noise that can throw of the machien leaning models. So it is very imporan to pre precosse the data in order to maximise accuraxy scores.
#
# **Lower Case**
#
# Converting all letters to lower case.
#
# **Noise Removal**
#
# I will remvoe all twitter handles, https links, and punuatuin because they add no meaing to the data. I will do thsi by using regualr Expressions.
#
# **Stopwords**
#
# Stopwards are words that add no meaing to the data. For exampel 'the', "this", 'is', 'I' are all stopwards and will be removed from the data. In order to do this, I must yokeneize the scentece. Tokinisxe is converitng scenteces into words.
#
# **Stemming**
#
# Takes out all he prefixes and suffixes of a word, so we are just left with the stem of a word. For example:
#
# *Working -> work*
# || *Worked -> work*
# || *Works -> work*

# %%
def words_to_label(s):
    if s == "negative":
        return 0
    elif s ==  "positive":
        return 1
def clean_tweets(tweet):
    tweet = tweet. lower()
    tweet = re.sub("@[A-Za-z0-9]*", "", tweet)
    tweet = re.sub("["+string.punctuation+"]", "", tweet)
    tweet_tokens = word_tokenize(tweet)
    sw = stopwords.words("english")
    tweet_tokens_filtered = []
    for token in tweet_tokens:
        if token not in sw and token.isalpha():
            tweet_tokens_filtered.append(token)  
    ps = PorterStemmer()
    tweet_tokens_filtered = [ps.stem(w) for w in tweet_tokens_filtered]
    tweet = " ".join(tweet_tokens_filtered)
    return tweet

# %%
df_nonClean["Label"] = df_nonClean["Sentiment"].apply(words_to_label)
df_nonClean["Clean Tweets"] = df_nonClean["Tweets"].apply(clean_tweets)
df_clean = df_nonClean.drop(columns=["Sentiment", "Tweets"]).copy()
df_clean
# Out:
#          Label                                       Clean Tweets
# 1037304      1                                      oh well thank
# 1001282      1                             readi gooood day besti
# 953146       1  definit diet day enjoy chees spinach pie follo...
# 881649       1                  li hing mui amp lemon good throat
# 1019895      1  would valu opinion work pressur fun particular...
# ...        ...                                                ...
# 277763       0  word wisdomif someon tell stori one assur pers...
# 360745       0                                          bodi hurt
# 310890       0                               back work zo tandart
# 329207       0                                    final begin hit
# 610773       0  hate paparazzi wait hour meet u pier u turner ...
#
# [400000 rows x 2 columns]

# %% [markdown]
# # Machine Learning
# **Vectorzing the data**
# For computers to understand the words in a tweet, I need to convert them to numbers. That is vectorizing the data: converting words to numbers. I will use TF-IDF Vectorizer to do that.
#
# TF-IDF is the Term Frequency times Inverse Document Frequency
#
# *Term Frequency (TF):*
# The TF of a word is the number of occurrences of the word in a tweet divided by the total number of words in the tweet:
#
# *Inverse Document Frequency(IDF):*
# IDF downscales weights for words that occur in many tweets and are therefore less informative than those that occur only in a smaller portion of the tweets.
#
# **Traning and Testing the models**
#
# I will slipt the data frame into four parts:
#
#     X_train: 80% of the tweets to train the model
# 	y_train: the sentiments relating to the tweets in X_train
# 	X_test: 20% of the tweets to test the model
# 	y_test: the sentiments relating to the tweets in X_test
#
# *To train the models*, I will pass in the X_trian and y_train data. *To test the models*, I will pass in X_test data and get back a list of predictions. I will compare the list of predictions to the y_test data and figure out the accuracy score.
#
# Each model has many parameters that I can fine-tune. In this example, I am just using the following standard models:
# *Multinomial Naive Bayes Model || SGD Classifier || Logistic Regression Classifier*

# %%
my_tfidfVectorizer = TfidfVectorizer(use_idf=True)
X = my_tfidfVectorizer.fit_transform(df_clean["Clean Tweets"])
y = df_clean["Label"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

time_dict = {}
accuracy_dict = {}

# %%
classifier_multinomialNB = MultinomialNB()
time = %timeit -q -o classifier_multinomialNB.fit(X_train, y_train)
predictions = classifier_multinomialNB.predict(X_test)

time_dict["MultinomialNB"] = round(time.average, 2)
accuracy_dict["MultinomialNB"] = round(accuracy_score(y_test, predictions)*100, 2)

# %%
classifier_SGDClassifier = SGDClassifier()
time = %timeit -q -o classifier_SGDClassifier.fit(X_train, y_train)
predictions = classifier_SGDClassifier.predict(X_test)

time_dict["SGDClassifier"] = round(time.average, 2)
accuracy_dict["SGDClassifier"] = round(accuracy_score(y_test, predictions)*100, 2)

# %%
classifier_LR_model = LogisticRegression(max_iter=1000)
time = %timeit -q -o classifier_LR_model.fit(X_train, y_train)
predictions = classifier_LR_model.predict(X_test)

time_dict["LogisticRegression"] = round(time.average, 2)
accuracy_dict["LogisticRegression"] = round(accuracy_score(y_test, predictions)*100, 2)

# %% [markdown]
# # The results
# In the following code, I made 2 bar graphs: Speed and Accuracy. As you can see, the **Multinomial Naive Bayes Model** model is extremely fast but is less accurate compared to the other models. On the other hand, the **Logistic Regression Classifier** is very slow, but it is the most accurate. *Moving forward, I will be using the Logistic Regression Classifier because it is the most accurate.*

# %%
fig = plt.figure(dpi = 300)
fig, ax = plt.subplots(1, 2, facecolor='#576692')
bar_time = plot_my_bargraph(ax[0], ["Multinomial NB", "SGD Classifier", "Logistic Regression"], list(time_dict.values()), ['#ffc801', '#ffa238', '#ffa238'], 0, int(time_dict["LogisticRegression"])+2, "Speed")
bar_accu = plot_my_bargraph(ax[1], ["Multinomial NB", "SGD Classifier", "Logistic Regression"], list(accuracy_dict.values()), ['#ffa238', '#ffa238', '#ffc801'], 70, 80, "Accuracy")
def add_bar_labels(ax, bars, yvalues, ending):
    for i in range(len(bars)):
        ax.annotate(str(yvalues[i])+ending, xy = (bars[i].get_x() + bars[i].get_width()/2 , bars[i].get_height()), xytext = (0, 4), textcoords = 'offset pixels', color = 'w', ha = 'center')
add_bar_labels(ax[0], bar_time, list(time_dict.values()), " secs")
add_bar_labels(ax[1], bar_accu, list(accuracy_dict.values()),  " %")

# %% [markdown]
# # Why does this matter
# **The use of sentiment analysis on the corporate side:**
#
# Sentiment analysis can identify critical issues in real-time; for example, is a PR crisis on social media escalating? Is an angry customer about to complain? Sentiment analysis models can help companies immediately identify these kinds of situations so that you can take action right away and minimize fallout.
#
# **The use of sentiment analysis on the user side:**
#
# Sentiment can also be a good indicator of a stock's value and health. The sentiment, along with other indicators, can give buy and sell signals for the stocks you own.
#
# **Bellow, I have two examples that show how Twitter tweets affected stocks. My simple model predicted each tweet's sentiment and how the stocks were affected after the tweet was sent out.**

# %%
def test_new_tweet(tweet):
    tweet_clean = clean_tweets(tweet)
    test_tweet = my_tfidfVectorizer.transform([tweet_clean])
    test_predict = classifier_LR_model.predict(test_tweet)
    print("Tweet: \''", tweet, "\''", sep='')
    if test_predict == 0:
        print("Prediction: The tweet is negative. Stock prices will go down.")
    elif test_predict == 1:
        print("Prediction: The tweet is postive. Stock prices will go up.")

def my_plot(ax, x_values, y_values, x_label, y_lable, title, tweetDate, y_value_at_tweet_date, image_name, img_offset, arrow_offset):
    plt.rc('axes', titlesize=15)     # fontsize of the axes title
    plt.rcParams["figure.figsize"] = [16,6]
    img = plt.imread(image_name, format='png')
    img = OffsetImage(img, zoom=.1)
    img = AnnotationBbox(img, [tweetDate,  y_value_at_tweet_date], xybox=img_offset, xycoords='data', boxcoords='offset pixels', pad=0,box_alignment=(0, 1), frameon=False)
    arrow = TextArea("")
    arrow = AnnotationBbox(arrow, [tweetDate,  y_value_at_tweet_date], xybox=arrow_offset, xycoords='data', pad=-10, boxcoords='offset pixels', frameon=False, arrowprops=dict(arrowstyle='->',color='w', ))
    ax.add_artist(img)
    ax.add_artist(arrow)
    ax.set_facecolor('#FA8769')
    ax.plot(x_values, y_values, '-o', color = "#D94E48", linewidth=3, markersize=8)
    ax.axvline(tweetDate, linestyle =  ':', color = 'w')
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_lable)
    ax.set_title(title)
    ax.xaxis.set_tick_params(rotation=30, labelsize=10)
    ax.yaxis.set_tick_params(labelsize=10)

# %%
test_new_tweet("Sooo does anyone else not open Snapchat anymore? Or is it just me... ugh this is so sad,")
snap_data = get_data("SNAP", start_date = "02/20/2018", end_date = "03/3/2018", index_as_date=False)
fig = plt.figure(dpi=300)
fig, ax1 = plt.subplots(1)
my_plot(ax1, snap_data["date"], snap_data["adjclose"], "Date", "Adjusted Closing Price", "How Kylie Jenner's tweet effected Snapchat's stock", snap_data.iloc[1][0], snap_data.iloc[1][5], "kylie_jenner_tweet.png", [100, 20], [100, 0])
# Out:
# Tweet: ''Sooo does anyone else not open Snapchat anymore? Or is it just me... ugh this is so sad,''
# Prediction: The tweet is negative. Stock prices will go down.

# %%
test_new_tweet("We currently have a large position in APPLE. We believe the company to be extremely undervalued. Spoke to Tim Cook today. More to come.")
appl_data = get_data("AAPL", start_date = "08/1/2013", end_date = "08/30/2013", index_as_date=False)
fig = plt.figure(dpi = 300)
fig, ax1 = plt.subplots(1)
my_plot(ax1, appl_data["date"], appl_data["adjclose"], "Date", "Adjusted Closing Price", "How billionaire Carl Icahn's tweet effected Apple's stock", appl_data.iloc[8][0], appl_data.iloc[8][5], "carl_icahn_tweet.png", [100, 20], [100, 0])
# Out:
# Tweet: ''We currently have a large position in APPLE. We believe the company to be extremely undervalued. Spoke to Tim Cook today. More to come.''
# Prediction: The tweet is postive. Stock prices will go up.
